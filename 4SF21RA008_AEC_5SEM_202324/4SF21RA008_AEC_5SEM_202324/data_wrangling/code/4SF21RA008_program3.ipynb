# %% [markdown]
# **Program 3** : Use regular expressions in Python to clean and preprocess text data effectively. Use the `re` module for pattern matching and text manipulation.

# %% [markdown]
# import pandas and Read data

# %%
import pandas as pd

df = pd.read_csv('build_data.csv')
df.head(40)
# Out:
#    Permit Number            Permit Type Definition Permit Creation Date  \
# 0   201404284346            otc alterations permit           04/28/2014
# 1        M432527            otc alterations permit           10/04/2013
# 2   201702159478            otc alterations permit           02/15/2017
# 3   201505287415            otc alterations permit           05/28/2015
# 4   201603222716            otc alterations permit           03/22/2016
# 5   201402037668            otc alterations permit           02/03/2014
# 6   201304094141            otc alterations permit           04/09/2013
# 7   201511102285            otc alterations permit           11/10/2015
# 8   201509096440            otc alterations permit           09/09/2015
# 9   201509247975            otc alterations permit           09/24/2015
# 10       M530587            otc alterations permit           10/24/2014
# 11  201603232853  additions alterations or repairs           03/23/2016
# 12  201606089354            otc alterations permit           06/08/2016
# 13  201408133771            otc alterations permit           08/13/2014
# 14  201611283589            otc alterations permit           11/28/2016
# 15       M413307            otc alterations permit           08/01/2013
# 16  201712075788                       demolitions           12/07/2017
# 17  201410169091            otc alterations permit           10/16/2014
# 18  201402219041  additions alterations or repairs           02/21/2014
# 19  201408284928            otc alterations permit           08/28/2014
# 20  201308154362            otc alterations permit           08/15/2013
# 21  201607223145            otc alterations permit           07/22/2016
# 22  201501064993            otc alterations permit           01/06/2015
# 23  201704063407  additions alterations or repairs           04/06/2017
# 24  201706209881            otc alterations permit           06/20/2017
# 25       M627367            otc alterations permit           10/06/2015
# 26       M800847            otc alterations permit           06/22/2017
# 27  201312093660            otc alterations permit           12/09/2013
# 28  201609097340            otc alterations permit           09/09/2016
# 29  201409095807  additions alterations or repairs           09/09/2014
# 30       M860747            otc alterations permit           11/30/2017
# 31  201306200071            otc alterations permit           06/20/2013
# 32  201305156940            otc alterations permit           05/15/2013
# 33  201412163806       new construction wood frame           12/16/2014
# 34  201606018843            otc alterations permit           06/01/2016
# 35       M714629            otc alterations permit           08/18/2016
# 36  201406128205            otc alterations permit           06/12/2014
# 37  201612074394  additions alterations or repairs           12/07/2016
# 38  201612074362            otc alterations permit           12/07/2016
# 39  201504163842            otc alterations permit           04/16/2015
#
#     Block   Lot  Street Number         Street Name  Unit  \
# 0    3544   045           1950                15th   NaN
# 1    1132   013             52             Almaden   NaN
# 2    0288   032            333                Bush   NaN
# 3    1101   018           1250           Broderick   NaN
# 4    3750   073            600            Harrison   NaN
# 5    6634  001B            133                29th   NaN
# 6    1722   011           1267                28th   NaN
# 7    0230   028              1  Embarcadero Center   NaN
# 8    6968   016           5034             Mission   NaN
# 9    1221   023            200             Central   NaN
# 10   0959   017           2775             Vallejo   NaN
# 11   7220   006           2968                19th   NaN
# 12   0603   036           2121             Jackson   2.0
# 13   5339   012           1665             Quesada   NaN
# 14   0998   001           3201          Washington   NaN
# 15   1237   010            922              Haight   NaN
# 16   2799   042             49             Hopkins   NaN
# 17   1523   032            460                22nd   0.0
# 18   3705   042            865              Market   NaN
# 19   3641   077           1269      South Van Ness   0.0
# 20   3780   006            888             Brannan   NaN
# 21   5871   030            282            Trumbull   NaN
# 22   4272   033           3027                25th   NaN
# 23   5297   027           1103              Phelps   NaN
# 24   1530  011A            469                14th   NaN
# 25   1389   017            286                30th   NaN
# 26   3544   067           2075              Market   NaN
# 27   1269   109            191              Downey   NaN
# 28   0918  002C           2300         North Point   NaN
# 29   3561   074           2295                15th   NaN
# 30   3736   006              1              Tehama   NaN
# 31   5956   039            119              Madrid   NaN
# 32   5959   026            171              Vienna   NaN
# 33  4591D   131              1                Earl   NaN
# 34   6515   009            370            Bartlett   NaN
# 35   3643   062            241            Bartlett   0.0
# 36   4098   038           1700                22nd   NaN
# 37   3763  015B            450              Bryant   NaN
# 38   0237   016            353          Sacramento   NaN
# 39   6656   065             42             Chenery   NaN
#
#                                           Description Current Status  ...  \
# 0   to obtain final inspection for work approved u...         issued  ...
# 1                                        street space         issued  ...
# 2   new freestanding benches to be added to plaza....         issued  ...
# 3   rmodel kitchen and bath. no structural work. s...       complete  ...
# 4   1st floor: fire alarm adding 5 duct horn/strob...       complete  ...
# 5   remove illegally constructed bath at garage an...         issued  ...
# 6   replace in kind - 5 double hung wood windows, ...       complete  ...
# 7   #1550- new supply ductwork, replace (e) pneuma...         issued  ...
# 8   to comply complaint #'s 201567801 & 201566821....       complete  ...
# 9   replace deteriorated window  sashes (53 total ...       complete  ...
# 10                                street space permit         issued  ...
# 11  horizontal addition at 2nd floor to extend bed...          filed  ...
# 12                                         reroofing.         issued  ...
# 13  to comply with nov. #200921913 to remove chain...       complete  ...
# 14  apt 7: add new wiring & subpanel. remodel kitc...       complete  ...
# 15  add new address to block 1237, lot 010 as; 922...         issued  ...
# 16  demolition of a two-story- no basement, single...          filed  ...
# 17  revision to pa# 201406259446. soft story seism...       complete  ...
# 18  house of hoops/footlocker: ti of existing reta...       complete  ...
# 19  unit a: replace kitchen cabinets & countertop,...       complete  ...
# 20     install of 34 evacuation maps from 1-5 floors.         issued  ...
# 21  kitchen remodel - no wallls moved, removed, ad...        expired  ...
# 22  to obtain final inspection for work approved u...       complete  ...
# 23  add 4 new residential units at ground floor to...          filed  ...
# 24  install flashing and siding. repair in-kind of...       complete  ...
# 25                                       street space         issued  ...
# 26                                       street space         issued  ...
# 27  to obtain final inspectionf or work approved u...       complete  ...
# 28  soft story retrofit per sfbc chapter 34b engin...       complete  ...
# 29  temporary shoring for the benefit of improveme...       approved  ...
# 30  per pa #201507272516, add address to block 373...         issued  ...
# 31  replace roof, siding and install new garage do...       complete  ...
# 32                                         re-roofing       complete  ...
# 33  bldg 3: construct new 3 stories, no basement, ...         issued  ...
# 34  develop level one storage into bedroom suite i...          filed  ...
# 35                                       street space         issued  ...
# 36          reroofing  (n/a maher ordinance # 155-13)         issued  ...
# 37  change of use from type "e" educational to typ...       complete  ...
# 38  22nd floor: t.i.  includes demo of nonstructur...       complete  ...
# 39  remodel 2 master baths, 1 at 3rd level, 1 at 4...       complete  ...
#
#    Number of Proposed Stories  Estimated Cost  Revised Cost  \
# 0                         3.0             1.0          1.00
# 1                         NaN             NaN          1.00
# 2                        43.0        113000.0     113000.00
# 3                         3.0         25600.0      25600.00
# 4                         6.0          3000.0       4000.00
# 5                         3.0             1.0       7500.00
# 6                         2.0          5000.0       5000.00
# 7                        45.0        180000.0     180000.00
# 8                         3.0           800.0        800.00
# 9                         4.0         30000.0      30000.00
# 10                        NaN             NaN          1.00
# 11                        3.0         40000.0           NaN
# 12                        3.0         17750.0      17750.00
# 13                        0.0          2500.0       2500.00
# 14                        3.0          1500.0      29722.00
# 15                        NaN             NaN        267.24
# 16                        NaN         15000.0           NaN
# 17                        4.0             1.0          1.00
# 18                        8.0        100000.0     725000.00
# 19                        2.0          5000.0       5000.00
# 20                        6.0          6000.0       6000.00
# 21                        1.0         20000.0      20000.00
# 22                        3.0             1.0          1.00
# 23                        3.0        100000.0           NaN
# 24                        4.0          2000.0       2000.00
# 25                        NaN             NaN          0.00
# 26                        NaN             NaN          1.00
# 27                        4.0             1.0          1.00
# 28                        4.0        100000.0     160000.00
# 29                        2.0         12000.0      70000.00
# 30                        NaN             NaN        243.66
# 31                        1.0          7000.0       7000.00
# 32                        2.0          8700.0       8700.00
# 33                        3.0       5000000.0    5000000.00
# 34                        3.0         25000.0      45000.00
# 35                        NaN             NaN          1.00
# 36                        2.0         24000.0      24000.00
# 37                        3.0             1.0      14400.00
# 38                       23.0        650000.0     650000.00
# 39                        4.0         80000.0      80000.00
#
#             Existing Use  Existing Units Supervisor District  \
# 0             apartments             3.0                 8.0
# 1                    NaN             NaN                 1.0
# 2                 office            45.0                 3.0
# 3             apartments            18.0                 5.0
# 4                 office             0.0                 6.0
# 5             apartments             5.0                 8.0
# 6      1 family dwelling             1.0                 4.0
# 7                 office             0.0                 3.0
# 8      2 family dwelling             2.0                11.0
# 9             apartments             8.0                 5.0
# 10                   NaN             NaN                 2.0
# 11     1 family dwelling             1.0                 7.0
# 12     2 family dwelling             2.0                 2.0
# 13            vacant lot             0.0                10.0
# 14            apartments            17.0                 2.0
# 15                   NaN             NaN                 5.0
# 16     1 family dwelling             1.0                 8.0
# 17            apartments             6.0                 1.0
# 18          retail sales             0.0                 6.0
# 19     2 family dwelling             2.0                 9.0
# 20                office             0.0                 6.0
# 21     1 family dwelling             1.0                11.0
# 22     2 family dwelling             2.0                 9.0
# 23            apartments             6.0                10.0
# 24            apartments             3.0                 1.0
# 25                   NaN             NaN                 2.0
# 26                   NaN             NaN                 8.0
# 27            apartments             4.0                 5.0
# 28            apartments            18.0                 2.0
# 29     1 family dwelling             1.0                 8.0
# 30                   NaN             NaN                 6.0
# 31  prkng garage/private             1.0                11.0
# 32     1 family dwelling             1.0                11.0
# 33                   NaN             NaN                10.0
# 34            apartments             4.0                 9.0
# 35                   NaN             NaN                 9.0
# 36     2 family dwelling             2.0                10.0
# 37                school             0.0                 6.0
# 38                office             0.0                 3.0
# 39     1 family dwelling             1.0                 8.0
#
#             Proposed Use  Proposed Units Plansets  Zipcode
# 0             apartments             3.0      0.0  94114.0
# 1                    NaN             NaN      NaN  94118.0
# 2                 office            45.0      2.0  94108.0
# 3             apartments            18.0      0.0  94115.0
# 4                 office             0.0      2.0  94107.0
# 5             apartments             5.0      2.0  94110.0
# 6      1 family dwelling             1.0      0.0  94122.0
# 7                 office             0.0      2.0  94111.0
# 8      2 family dwelling             2.0      0.0  94112.0
# 9             apartments             8.0      2.0  94117.0
# 10                   NaN             NaN      NaN  94123.0
# 11     1 family dwelling             1.0      2.0  94132.0
# 12     2 family dwelling             2.0      0.0  94115.0
# 13            vacant lot             0.0      0.0  94124.0
# 14            apartments            17.0      0.0  94115.0
# 15                   NaN             NaN      NaN  94117.0
# 16                   NaN             NaN      2.0  94131.0
# 17            apartments             6.0      2.0  94121.0
# 18          retail sales             0.0      2.0  94103.0
# 19     2 family dwelling             2.0      0.0  94110.0
# 20                office             0.0      2.0  94103.0
# 21     1 family dwelling             1.0      0.0  94112.0
# 22     2 family dwelling             2.0      0.0  94110.0
# 23            apartments            10.0      2.0  94124.0
# 24            apartments             3.0      0.0  94118.0
# 25                   NaN             NaN      NaN  94121.0
# 26                   NaN             NaN      NaN  94114.0
# 27            apartments             4.0      0.0  94117.0
# 28            apartments            18.0      2.0  94123.0
# 29     1 family dwelling             1.0      2.0  94114.0
# 30                   NaN             NaN      NaN  94105.0
# 31  prkng garage/private             1.0      0.0  94112.0
# 32     1 family dwelling             1.0      0.0  94112.0
# 33            apartments            11.0      2.0  94124.0
# 34            apartments             4.0      2.0  94110.0
# 35                   NaN             NaN      NaN  94110.0
# 36     2 family dwelling             2.0      0.0  94107.0
# 37                office             0.0      2.0  94107.0
# 38                office             0.0      2.0  94111.0
# 39     1 family dwelling             1.0      2.0  94131.0
#
# [40 rows x 22 columns]

# %% [markdown]
# find the data types in each fields. find the data type of block column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676 entries, 0 to 2675
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Permit Number               2676 non-null   object
#  1   Permit Type Definition      2676 non-null   object
#  2   Permit Creation Date        2676 non-null   object
#  3   Block                       2676 non-null   object
#  4   Lot                         2676 non-null   object
#  5   Street Number               2676 non-null   int64
#  6   Street Name                 2676 non-null   object
#  7   Unit                        365 non-null    float64
#  8   Description                 2674 non-null   object
#  9   Current Status              2676 non-null   object
#  10  Structural Notification     82 non-null     object
#  11  Number of Existing Stories  2078 non-null   float64
#  12  Number of Proposed Stories  2075 non-null   float64
#  13  Estimated Cost              2138 non-null   float64
#  14  Revised Cost                2601 non-null   float64
#  15  Existing Use                2104 non-null   object
#  16  Existing Units              1963 non-null   float64
#  17  Supervisor District         2654 non-null   float64
#  18  Proposed Use                2086 non-null   object
#  19  Proposed Units              1974 non-null   float64
#  20  Plansets                    2147 non-null   float64
#  21  Zipcode                     2654 non-null   float64
# dtypes: float64(10), int64(1), object(11)
# memory usage: 460.1+ KB

# %% [markdown]
# Try to convert object datatype to int. You will get an error

# %%
df['Block'] = df['Block'].astype(int)

# %% [markdown]
# Import regular expressions package regex. Change the field to regular expression.
#
# Syntax for re.sub() is
# re.sub(pattern,replacement,string[, count,flags])

# %%
import re

block_list = []
for string in df['Block']:
  #use the re.sub function to remove all the non umeric characters of the string.
  normal_string = re.sub('[^0-9]',"",string)
  #store it in updated list called block_list that you have initialised
  block_list.append(normal_string)

#assign the values of updated list called block_list to Block column
df['Block'] = block_list

# %% [markdown]
# Again try to change the code

# %%
df['Block'] =df['Block'].astype(int)

# %% [markdown]
# Again , check if the field is changed to int type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676 entries, 0 to 2675
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Permit Number               2676 non-null   object
#  1   Permit Type Definition      2676 non-null   object
#  2   Permit Creation Date        2676 non-null   object
#  3   Block                       2676 non-null   int64
#  4   Lot                         2676 non-null   object
#  5   Street Number               2676 non-null   int64
#  6   Street Name                 2676 non-null   object
#  7   Unit                        365 non-null    float64
#  8   Description                 2674 non-null   object
#  9   Current Status              2676 non-null   object
#  10  Structural Notification     82 non-null     object
#  11  Number of Existing Stories  2078 non-null   float64
#  12  Number of Proposed Stories  2075 non-null   float64
#  13  Estimated Cost              2138 non-null   float64
#  14  Revised Cost                2601 non-null   float64
#  15  Existing Use                2104 non-null   object
#  16  Existing Units              1963 non-null   float64
#  17  Supervisor District         2654 non-null   float64
#  18  Proposed Use                2086 non-null   object
#  19  Proposed Units              1974 non-null   float64
#  20  Plansets                    2147 non-null   float64
#  21  Zipcode                     2654 non-null   float64
# dtypes: float64(10), int64(2), object(10)
# memory usage: 460.1+ KB

# %% [markdown]
# Write the Cleaned dataset to an output csv file

# %%
# Specify the output Excel file path
output_file = 'Datacleaned_output.csv'

# Write the specified field to Excel
df.to_csv(output_file, index=False)

# %% [markdown]
# Conclusion: Regular expressions prove to be a powerful tool for pattern matching and text manipulation, especially in scenarios like cleaning textual data.
# Despite encountering initial errors, the program successfully cleans the 'Block' column and converts it to the desired data type.
# Writing the cleaned dataset to an output file ensures that the preprocessed data is available for further analysis or use in downstream tasks.
# This program demonstrates a practical approach to data cleaning using regex, which is a crucial step in the data preprocessing pipeline for text data.
